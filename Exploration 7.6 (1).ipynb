# %% [markdown]
# # Exploration 7.6

# %%
def f(t,y):
    return np.exp(t)*np.sin(y)

# %%
def soln(t):
    return 2 * np.arctan(1 / (17.9858 * np.exp(-np.exp(t))))

# %%
import math

def euler_method(t0, y0, h, t_end):
    t = t0
    y = y0
    while t < t_end:
        y += h * math.exp(t) * math.sin(y)
        t += h
    return y

# Given values
t0 = 0
y0 = 0.30
h = 0.30
t_end = 10

y_10 = euler_method(t0, y0, h, t_end)
print("Approximate value of y(10) using Euler's method:", y_10)
# Out:
# Approximate value of y(10) using Euler's method: 10909.871541508808

# %%
analytical_prediction= soln(10)

ratio= y_10/analytical_prediction
print("Analytical prediction of y(10) is", analytical_prediction)
print("Ratio of numerical vs analytical is", ratio)
# Out:
# Analytical prediction of y(10) is 3.141592653589793
# Ratio of numerical vs analytical is 3472.719968657446
# C:\Users\Hasif\AppData\Local\Temp\ipykernel_31412\1519247141.py:2: RuntimeWarning: divide by zero encountered in double_scalars
#   return 2 * np.arctan(1 / (17.9858 * np.exp(-np.exp(t))))

# %% [markdown]
# We see the numerical approximation blow up as it is nowhere close to analytical solution of $y(10)$
#
# _____

# %% [markdown]
# 3
#
# We now vary our stepsizes

# %%
import math

def euler_method(t0, y0, h, t_end):
    t = t0
    y = y0
    while t < t_end:
        y += h * math.exp(t) * math.sin(y)
        t += h
    return y

# Given values
t0 = 0
y0 = 0.001
h = 0.001 
t_end = 10

y_10 = euler_method(t0, y0, h, t_end)
print("Approximate value of y(10) using Euler's method:", y_10)
# Out:
# Approximate value of y(10) using Euler's method: -1179.6728318223827

# %%
import math

def euler_method(t0, y0, h, t_end):
    t = t0
    y = y0
    while t < t_end:
        y += h * math.exp(t) * math.sin(y)
        t += h
    return y

# Given values
t0 = 0
y0 = 0.002
h = 0.002
t_end = 10

y_10 = euler_method(t0, y0, h, t_end)
print("Approximate value of y(10) using Euler's method:", y_10)
# Out:
# Approximate value of y(10) using Euler's method: 522.1741061875068

# %%
import math

def euler_method(t0, y0, h, t_end):
    t = t0
    y = y0
    while t < t_end:
        y += h * math.exp(t) * math.sin(y)
        t += h
    return y

# Given values
t0 = 0
y0 = 0.003
h = 0.003
t_end = 10

y_10 = euler_method(t0, y0, h, t_end)
print("Approximate value of y(10) using Euler's method:", y_10)
# Out:
# Approximate value of y(10) using Euler's method: -462.84192139051936

# %% [markdown]
# We see that for little perturbations to initial conditions the y(10) varies drastically-- For 0.001, the prediction is -1179.6728318223827 and For stepsize 0.002, the prediction is 522.1741061875068 and for stepsize 0.003 the prediction is -462.84192139051936. This shows the sensitivity of initial condition variance
#
# _____
# 4/ Now we perturb our initial conditions

# %%
import math

def euler_method(t0, y0, h, t_end):
    t = t0
    y = y0
    while t < t_end:
        y += h * math.exp(t) * math.sin(y)
        t += h
    return y

# Given values
t0 = 0
y0 = 0.301
h = 0.30
t_end = 10

y_10 = euler_method(t0, y0, h, t_end)
print("Approximate value of y(10) using Euler's method:", y_10)
# Out:
# Approximate value of y(10) using Euler's method: -683.260730706581

# %%
import math

def euler_method(t0, y0, h, t_end):
    t = t0
    y = y0
    while t < t_end:
        y += h * math.exp(t) * math.sin(y)
        t += h
    return y

# Given values
t0 = 0
y0 = 0.302
h = 0.30
t_end = 10

y_10 = euler_method(t0, y0, h, t_end)
print("Approximate value of y(10) using Euler's method:", y_10)
# Out:
# Approximate value of y(10) using Euler's method: 12467.542923116842

# %% [markdown]
# Notice how varying initial conditions from y(0)= 0.30 to y(0)=0.31, 0.32 changes our numerical approximation drastically. Given subtle perturbations to initial conditions bring these drastic changes we can claim that it exhibits sensitive dependence on initial conditions
# ____
#
# We now throw our hand at using Runge-Kutta method for the numerical approximation

# %%
import math

def f(t, y):
    return math.exp(t) * math.sin(y)

def runge_kutta_4th_order(t0, y0, h, t_end):
    t = t0
    y = y0
    while t < t_end:
        k1 = h * f(t, y)
        k2 = h * f(t + 0.5*h, y + 0.5*k1)
        k3 = h * f(t + 0.5*h, y + 0.5*k2)
        k4 = h * f(t + h, y + k3)

        y += (k1 + 2*k2 + 2*k3 + k4) / 6.0
        t += h
    return y

# Given values
t0 = 0
y0 = 0.3
h = 0.3
t_end = 10

y_10 = runge_kutta_4th_order(t0, y0, h, t_end)
print("Approximate value of y(10) using 4th order Runge-Kutta method:", y_10)
# Out:
# Approximate value of y(10) using 4th order Runge-Kutta method: 13386.789636711563

# %% [markdown]
# Now, let's vary stepsizes

# %%
import math

def f(t, y):
    return math.exp(t) * math.sin(y)

def runge_kutta_4th_order(t0, y0, h, t_end):
    t = t0
    y = y0
    while t < t_end:
        k1 = h * f(t, y)
        k2 = h * f(t + 0.5*h, y + 0.5*k1)
        k3 = h * f(t + 0.5*h, y + 0.5*k2)
        k4 = h * f(t + h, y + k3)

        y += (k1 + 2*k2 + 2*k3 + k4) / 6.0
        t += h
    return y

# Given values
t0 = 0
y0 = 0.30
h = 0.001
t_end = 10

y_10 = runge_kutta_4th_order(t0, y0, h, t_end)
print("Approximate value of y(10) using 4th order Runge-Kutta method:", y_10)
# Out:
# Approximate value of y(10) using 4th order Runge-Kutta method: 830.3944247777524

# %%
import math

def f(t, y):
    return math.exp(t) * math.sin(y)

def runge_kutta_4th_order(t0, y0, h, t_end):
    t = t0
    y = y0
    while t < t_end:
        k1 = h * f(t, y)
        k2 = h * f(t + 0.5*h, y + 0.5*k1)
        k3 = h * f(t + 0.5*h, y + 0.5*k2)
        k4 = h * f(t + h, y + k3)

        y += (k1 + 2*k2 + 2*k3 + k4) / 6.0
        t += h
    return y

# Given values
t0 = 0
y0 = 0.30
h = 0.002
t_end = 10

y_10 = runge_kutta_4th_order(t0, y0, h, t_end)
print("Approximate value of y(10) using 4th order Runge-Kutta method:", y_10)
# Out:
# Approximate value of y(10) using 4th order Runge-Kutta method: -105.35173254917531

# %%
import math

def f(t, y):
    return math.exp(t) * math.sin(y)

def runge_kutta_4th_order(t0, y0, h, t_end):
    t = t0
    y = y0
    while t < t_end:
        k1 = h * f(t, y)
        k2 = h * f(t + 0.5*h, y + 0.5*k1)
        k3 = h * f(t + 0.5*h, y + 0.5*k2)
        k4 = h * f(t + h, y + k3)

        y += (k1 + 2*k2 + 2*k3 + k4) / 6.0
        t += h
    return y

# Given values
t0 = 0
y0 = 0.30
h = 0.003
t_end = 10

y_10 = runge_kutta_4th_order(t0, y0, h, t_end)
print("Approximate value of y(10) using 4th order Runge-Kutta method:", y_10)
# Out:
# Approximate value of y(10) using 4th order Runge-Kutta method: 161.6033865748213

# %% [markdown]
# We see that there is qualitively no change in the numerical approximations being way far from the analytical solution of $\pi$ even after using Runge-Kutta method.

# %% [markdown]
# We want to find similar differential equations where numerical methods break down. Let's check $y'(t)= e^t cos(y)$ with initial conditions $y(0)=1$

# %%
import math

def f(t, y):
    return math.exp(t) * math.cos(y)

def runge_kutta_4th_order(t0, y0, h, t_end):
    t = t0
    y = y0
    while t < t_end:
        k1 = h * f(t, y)
        k2 = h * f(t + 0.5*h, y + 0.5*k1)
        k3 = h * f(t + 0.5*h, y + 0.5*k2)
        k4 = h * f(t + h, y + k3)

        y += (k1 + 2*k2 + 2*k3 + k4) / 6.0
        t += h
    return y

# Given values
t0 = 0
y0 = 1
h = 0.30
t_end = 10

y_10 = runge_kutta_4th_order(t0, y0, h, t_end)
print("Approximate value of y(10) using 4th order Runge-Kutta method:", y_10)
# Out:
# Approximate value of y(10) using 4th order Runge-Kutta method: -1348.0925793566998

# %%
import math

def f(t, y):
    return math.exp(t) * math.cos(y)

def runge_kutta_4th_order(t0, y0, h, t_end):
    t = t0
    y = y0
    while t < t_end:
        k1 = h * f(t, y)
        k2 = h * f(t + 0.5*h, y + 0.5*k1)
        k3 = h * f(t + 0.5*h, y + 0.5*k2)
        k4 = h * f(t + h, y + k3)

        y += (k1 + 2*k2 + 2*k3 + k4) / 6.0
        t += h
    return y

# Given values
t0 = 0
y0 = 1
h = 0.301
t_end = 10

y_10 = runge_kutta_4th_order(t0, y0, h, t_end)
print("Approximate value of y(10) using 4th order Runge-Kutta method:", y_10)
# Out:
# Approximate value of y(10) using 4th order Runge-Kutta method: -5256.425904070151

# %% [markdown]
# Notice that slight perturbations in the stepsize show familiar chaotic properties. So this is also a differential equation where numerical schemes break down
